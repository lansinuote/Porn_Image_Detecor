# %%
import requests
import re

host = 'https://wallhaven.cc/search?'

params = {
    'categories': '111',
    'purity': '111',
    'ratios': '16x9',
    'sorting': 'random',
    'order': 'desc',
    'seed': 'VmpoF1',
    'page': '2'
}

headers = {
    'accept': 'text/html, */*; q=0.01',
    'accept-language':
    'zh-CN,zh;q=0.9,en;q=0.8,ja;q=0.7,zh-TW;q=0.6,de;q=0.5,pt;q=0.4',
    'cookie':
    'remember_web_59ba36addc2b2f9401580f014c7f58ea4e30989d=; XSRF-TOKEN=eyJpdiI6IkNlYWt2dWxVVmZwNjBIOU0xXC9aTDFnPT0iLCJ2YWx1ZSI6IjNIS3FFclg2Q0x5blUrOHUyMk9Ca2ZueHpQcjVzalpBcU1ITXoyUlwveXA2VHBrZ1luelZtejRwU3p0QlwvbFwvRU4iLCJtYWMiOiIwMTUwYzg5OGU0ZTFhMGM2NDU1MTk2MzZhZjQ1ZmM2NjhmZGQzMDkwM2NmYmM2Y2M0ZmI2NGViNGQ4NjhjZDIxIn0%3D; wallhaven_session=eyJpdiI6ImRFMWw2NVNSKzZGS3FQcnFBb0RpeXc9PSIsInZhbHVlIjoiNzg4N1ZHOFwvTjh6b09wSkJuUmZjSUtTeXBzTzRpSnM4STArWEtsZ3NOY2tHMlwvUmV5OUVZOW13XC92WHB2OHlOOSIsIm1hYyI6IjkwMWViY2I0NmE3ODg2ODQxZjZlODNhOTc3ZjUzYWE3OGE4MWIyNTVmYzQ3Y2EwNTEyNDk3MDM1YzIwOWJmMmUifQ%3D%3D',
    'referer':
    'https://wallhaven.cc/search?categories=111&purity=111&ratios=16x9&sorting=random&order=desc',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent':
    'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}

for i in range(2, 2002):
    params['page'] = str(i)
    text = requests.get(host, params=params, headers=headers).text

    figures = re.findall('<figure.*?</figure>', text)

    for f in figures:
        classes = re.findall('<figure  class="(.*?)"', f)[0].split(' ')

        line = ''

        if classes[2] == 'thumb-sfw':
            line += '0,'
        if classes[2] == 'thumb-sketchy':
            line += '1,'
        if classes[2] == 'thumb-nsfw':
            line += '2,'

        if classes[3] == 'thumb-general':
            line += '0,'
        if classes[3] == 'thumb-anime':
            line += '1,'
        if classes[3] == 'thumb-people':
            line += '2,'

        line += re.findall('data-src="(.*?)"', f)[0]

        with open('./wallhaven.csv', 'a') as f:
            f.write(line + '\n')
            
    if i % 50 == 0:
        print(i)
# Out:
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
